
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 43 of set 11 | talawdi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# CITY NOT FOUND
# Processing record 44 of set 11 | bialogard
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 45 of set 11 | beira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 46 of set 11 | san andres
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 47 of set 11 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 48 of set 11 | agadez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 49 of set 11 | kawalu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 50 of set 11 | delfzijl
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 0 of set 12 | orange walk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 1 of set 12 | tabialan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# CITY NOT FOUND
# Processing record 2 of set 12 | tiarei
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 3 of set 12 | amapa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 4 of set 12 | westport
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 5 of set 12 | frontera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 6 of set 12 | imphal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 7 of set 12 | mabaruma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 8 of set 12 | surt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# Processing record 9 of set 12 | mrirt
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=e05ae857d8b8eddc32b3119ca68b5cb7
# CITY NOT FOUND

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
weather_info_dict = {
    "City": new_cities,
    "Cloudiness" : cloudiness,
    "Country" : country,
    "Date" : date,
    "Humidity" : humidity,
    "Temp": temp,
    "Lat" : lat,
    "Lng" : lng,   
    "Wind Speed" : wind
}
weather_df = pd.DataFrame(weather_info_dict)
weather_df.count()
# Out:
# City          570
# Cloudiness    570
# Country       570
# Date          570
# Humidity      570
# Temp          570
# Lat           570
# Lng           570
# Wind Speed    570
# dtype: int64

# %%
weather_df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity   Temp    Lat  \
# 0         hilo          40      US  1587261871        54  82.40  19.73
# 1       avarua          79      CK  1587261872        65  82.40 -21.21
# 2      rikitea          71      PF  1587261872        69  77.45 -23.12
# 3  east london           0      ZA  1587261872        61  68.09 -33.02
# 4      manggar          97      ID  1587261872        68  86.68  -2.88
#
#       Lng  Wind Speed
# 0 -155.09       10.29
# 1 -159.78        9.17
# 2 -134.97        7.36
# 3   27.91       14.14
# 4  108.27        4.18

# %%
#export data as a csv
weather_df.to_csv("weatherdata.csv", index=False, header=True)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Temp"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Temperature")
plt.ylabel("Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("TemperatureInWorldCities.png")

# Show plot
plt.show()

# %%
# The Temperature in World Cities data and scatter plot is gathering temperatures among cities, which is analyzed and shown across a latitude range.

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("HumidityInWorldCities.png")

# Show plot
plt.show()

# %%
# The Humidity in World Cities data and scatter plot is gathering humidity percantages among cities, which is analyzed and shown across a latitude range.

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("CloudinessInWorldCities.png")

# Show plot
plt.show()

# %%
# The Cloudiness in World Cities data and scatter plot is gathering a percentage cloudiness among cities, which is analyzed and shown across a latitude range.

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("WindSpeedInWorldCities.png")

# Show plot
plt.show()

# %%
# The Wind Speed in World Cities data and scatter plot is gathering wind speed, in mph, among cities, which is analyzed and shown across a latitude range.

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
#IDEA - need to use latitudes below
#(-60,10) - Southern 
#(10,80) - Northern

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(weather_df["Lat"], weather_df["Temp"], marker="o")

plt.title("Southern - Max Temp vs. Latitude")
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.xlim(10,80)
plt.grid(True)

x_values = weather_df["Lat"]
y_values = weather_df["Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.43775205402607864

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
plt.scatter(weather_df["Lat"], weather_df["Temp"], marker="o")

plt.title("Northern - Max Temp vs. Latitude")
plt.ylabel("Max Temp (F)")
plt.xlabel("Latitude")
plt.xlim(-10,60)
plt.grid(True)

x_values = weather_df["Lat"]
y_values = weather_df["Temp"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.43775205402607864

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o")

plt.title("Northern - Humidity vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.xlim(10,80)
plt.grid(True)

x_values = weather_df["Lat"]
y_values = weather_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00486763589576075

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
plt.scatter(weather_df["Lat"], weather_df["Humidity"], marker="o")

plt.title("Southern - Humidity vs. Latitude")
plt.ylabel("Humidity")
plt.xlabel("Latitude")
plt.xlim(-60,10)
plt.grid(True)

x_values = weather_df["Lat"]
y_values = weather_df["Humidity"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00486763589576075

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o")

plt.title("Northern - Cloudiness vs. Latitude")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.xlim(10,80)
plt.grid(True)

x_values = weather_df["Lat"]
y_values = weather_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.003955085414082325

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
plt.scatter(weather_df["Lat"], weather_df["Cloudiness"], marker="o")

plt.title("Southern - Cloudiness vs. Latitude")
plt.ylabel("Cloudiness")
plt.xlabel("Latitude")
plt.xlim(-60,10)
plt.grid(True)

x_values = weather_df["Lat"]
y_values = weather_df["Cloudiness"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.003955085414082325

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o")

plt.title("Northern - Wind Speed vs. Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.xlim(10,80)
plt.grid(True)

x_values = weather_df["Lat"]
y_values = weather_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00967932052980376

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
plt.scatter(weather_df["Lat"], weather_df["Wind Speed"], marker="o")

plt.title("Northern - Max Temp vs. Latitude")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.xlim(-60,10)
plt.grid(True)

x_values = weather_df["Lat"]
y_values = weather_df["Wind Speed"]
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
plt.scatter(x_values,y_values)
plt.plot(x_values,regress_values,"r-")
plt.annotate(line_eq,(0,50),fontsize=15,color="red")
print(f"The r-squared is: {rvalue**2}")
plt.show()
# Out:
# The r-squared is: 0.00967932052980376
